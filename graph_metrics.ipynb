# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df_unet1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_resnet/metrics_unet.csv")
df_unet2 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_resnet/metrics_unet_pretrained.csv")

# %%
df_eff1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_eff/training_metrics_eff1.csv")
df_eff2 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_eff/metrics_uneteff_retrain_valid.csv")

# %%
df_deep1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_deeplab/training_metrics_deeplab.csv")
df_deep2 = pd.read_excel("/Users/jenniferpatricia/1_kuliah/thesis/unet_deeplab/training_deeplab_pretrained.xlsx")

# %%
# df_unet1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_resnet/metrics_unet.csv")
# df_unet2 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_resnet/metrics_resnet_retrain_valid.csv")

# df_eff1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_eff/training_metrics_eff1.csv")
# df_eff2 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_eff/metrics_uneteff_retrain_valid.csv")

# df_deep1 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_deeplab/training_metrics_deeplab.csv")
# df_deep2 = pd.read_csv("/Users/jenniferpatricia/1_kuliah/thesis/unet_deeplab/metrics_deeplab_retrain_valid.csv")

# %%
df_unet2 = df_unet2.head(20)
df_eff2 = df_eff2.head(20)
df_deep2 = df_deep2.head(20)

df_unet2["epoch"] += 20
df_eff2["epoch"] += 20
df_deep2["epoch"] += 20

df_unet_all = pd.concat([df_unet1, df_unet2], ignore_index=True)
df_eff_all  = pd.concat([df_eff1, df_eff2], ignore_index=True)
df_deep_all = pd.concat([df_deep1, df_deep2], ignore_index=True)

# %% [markdown]
# ## train & val loss

# %%
sns.lineplot(df_unet_all,x="epoch", y = "tr_loss", label="train_loss")
sns.lineplot(df_unet_all,x="epoch", y= "va_loss", label="val_loss")
plt.legend(title="Unet+Resnet18")

# %%
# sns.lineplot(df_unet2,x="epoch", y = "tr_loss", label="train_loss")
# sns.lineplot(df_unet2,x="epoch", y= "va_loss", label="val_loss")
# plt.legend(title="Unet+Resnet18 (thr:0.15)")

# %%
sns.lineplot(df_unet_all,x="epoch", y = "tr_f1", label="train_f1", color="#006400")
sns.lineplot(df_unet_all,x="epoch", y = "va_f1", label="val_f1", color="#5EE75E")
plt.legend(title="Unet+Resnet18")

# %%
sns.lineplot(df_eff_all,x="epoch", y = "tr_loss", label="train_loss")
sns.lineplot(df_eff_all,x="epoch", y= "va_loss", label="val_loss")
plt.legend(title="Unet+EfficientNet-b4")

# %%
sns.lineplot(df_eff_all,x="epoch", y = "tr_f1", label="train_f1", color="#006400")
sns.lineplot(df_eff_all,x="epoch", y = "va_f1", label="val_f1", color="#5EE75E")
plt.legend(title="Unet+EfficientNet-b4 (thr:0.05)")

# %%
sns.lineplot(df_deep_all,x="epoch", y = "tr_loss", label="train_loss")
sns.lineplot(df_deep_all,x="epoch", y= "va_loss", label="val_loss")
plt.legend(title="Deeplab+EfficientNet-b4")

# %%
sns.lineplot(df_deep_all,x="epoch", y = "tr_f1", label="train_f1", color="#006400")
sns.lineplot(df_deep_all,x="epoch", y = "va_f1", label="val_f1", color="#5EE75E")
plt.legend(title="Deeplab+EfficientNet-b4 (thr:0.05)")

# %% [markdown]
# ### f1

# %%
sns.lineplot(df_unet_all,x="epoch", y = "va_f1", label="Unet+Resnet18")
sns.lineplot(df_eff_all,x="epoch", y= "va_f1", label="Unet+EfficientNet-b4 ")
sns.lineplot(df_deep_all,x="epoch", y= "va_f1", label="Deeplab+EfficientNet-b4")
plt.legend(title="Models")

# %%
sns.lineplot(df_unet2,x="epoch", y = "va_f1", label="Unet+Resnet18 (thr:0.15)")
sns.lineplot(df_eff2,x="epoch", y= "va_f1", label="Unet+EfficientNet-b4 (thr:0.05)")
sns.lineplot(df_deep2,x="epoch", y= "va_f1", label="Deeplab+EfficientNet-b4 (thr:0.05)")
plt.legend(title="Models")

# %% [markdown]
# # auc
